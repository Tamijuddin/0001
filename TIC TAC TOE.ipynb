# %%
from IPython.display import clear_output

def display_board(board):
    
    clear_output()
    print(' ' + board[7] + ' | ' + board[8] + ' | ' + board[9])
    print(' ' + board[4] + ' | ' + board[5] + ' | ' + board[6])
    print(' ' + board[1] + ' | ' + board[2] + ' | ' + board[3])
        
    
def win_check(board,mark):
    
    return ((board[7] == board[8] == board[9] == mark) or # across the top
    (board[4] == board[5] ==board[6] == mark) or # across the middle
    (board[1] == board[2] ==board[3] == mark) or # across the bottom
    (board[7] == board[4] ==board[1] == mark) or # down the middle
    (board[8] == board[5] ==board[2] == mark) or # down the middle
    (board[9] == board[6] ==board[3] == mark) or # down the right side
    (board[7] == board[5] ==board[3] == mark) or # diagonal
    (board[9] == board[5] ==board[1] == mark)) # diagonal

import random    
def turn_generator():
    turn=random.randint(0,1)
    if turn==0:
        return 'Player 1'
    else:
        return 'Player 2'
    
def user_input(board):
    position=''
    while True:
        position=int(input('Choose a position between 1-9 : '))
        if board[position] != ' ':
            print('-----Enter proper position-----')
            continue
        else:
            return position

def mark_generate(board):
    mark=''
    while not (mark=='X' or mark=='O'):
        mark=input('Choose X or O : ').upper()
        if mark=='X':
            return ('X','O')
        else:
            return ('O','X')
    
def space_check(board,position):
    return (board[position]==' ')

def full_board_check(board):
    for i in range(1,10):
        if space_check(board,i):
            return False
    return True

def board_marker(board,position,mark):
    board[position]=mark
    
def play_again():
    choice=input('Play again? Y/N: ').upper()
    if choice=='Y':
        print("\t\t\t\t\t\tNew Game\t\t\t\t\t\t")
        return True
    else:
        print("\t\t\t\t\t\tExit Game\t\t\t\t\t\t")
        return False

# %%
print('WELCOME TO TIC TAC TOE GAME!!')

while True:
    
    board=[' ']*10
    player1,player2=mark_generate(board)
    turn=turn_generator()
    print(turn + ' will go first')
    play_game=input('Play Game? Y/N: ').upper()
    if play_game=='Y':
        game_on= True
    else:
        print('Exiting Game....')
        game_on= False
        break
    
    
    while game_on:
        
        if turn=='Player 1':
            display_board(board)
            position=user_input(board)
            board_marker(board,position,player1)
            
            if win_check(board,player1):
                display_board(board)
                print('PLAYER 1 WON!!')
                game_on=False
            else:
                if full_board_check(board):
                    display_board(board)
                    print('TIE GAME!!')
                    game_on=False
                
                else:
                    turn='Player 2'
        
        else:
            display_board(board)
            position=user_input(board)
            board_marker(board,position,player2)
            
            if win_check(board,player2):
                display_board(board)
                print('PLAYER 2 WON!!')
                game_on=False
            else:
                if full_board_check(board):
                    display_board(board)
                    print('TIE GAME!!')
                    game_on=False
                
                else:
                    turn='Player 1'
        
        

    if not play_again():
        break
# Out:
# WELCOME TO TIC TAC TOE GAME!!
# Choose X or O : o
# Player 2 will go first
# Play Game? Y/N: n
# Exiting Game....
